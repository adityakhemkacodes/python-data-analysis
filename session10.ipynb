# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("/content/matches.csv")

# %%
df2=pd.read_csv('balls.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df1['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df1['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df1['team1'].nunique()
# Out:
# 15

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df2
# Out:
#            id  inning  over  ball      batsman  non_striker     bowler  \
# 0      335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1      335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2      335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3      335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4      335982       1     7     3   RT Ponting  BB McCullum     Z Khan
# ...       ...     ...   ...   ...          ...          ...        ...
# 98740  729313       2     4     1    CA Pujara     V Sehwag   AB Dinda
# 98741  729313       2     4     2      WP Saha     V Sehwag   AB Dinda
# 98742  729313       2     4     3      WP Saha     V Sehwag   AB Dinda
# 98743  729313       2     4     4     V Sehwag      WP Saha   AB Dinda
# 98744  729313       2     4     5     V Sehwag      WP Saha   AB Dinda
#
#        batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# ...

# %%
df1.head
# Out:
# <bound method NDFrame.head of           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
df2.head
# Out:
# <bound method NDFrame.head of            id  inning  over  ball      batsman  non_striker     bowler  \
# 0      335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1      335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2      335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3      335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4      335982       1     7     3   RT Ponting  BB McCullum     Z Khan
# ...       ...     ...   ...   ...          ...          ...        ...
# 98740  729313       2     4     1    CA Pujara     V Sehwag   AB Dinda
# 98741  729313       2     4     2      WP Saha     V Sehwag   AB Dinda
# 98742  729313       2     4     3      WP Saha     V Sehwag   AB Dinda
# 98743  729313       2     4     4     V Sehwag      WP Saha   AB Dinda
# 98744  729313       2     4     5     V Sehwag      WP Saha   AB Dinda
#
#        batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# ...

# %%
df2.iloc[0]  #first ball
# Out:
# id                                       335982
# inning                                        1
# over                                          6
# ball                                          5
# batsman                              RT Ponting
# non_striker                         BB McCullum
# bowler                                AA Noffke
# batsman_runs                                  1
# extra_runs                                    0
# total_runs                                    1
# non_boundary                                  0
# is_wicket                                     0
# dismissal_kind                              NaN
# player_dismissed                            NaN
# fielder                                     NaN
# extras_type                                 NaN
# batting_team              Kolkata Knight Riders
# bowling_team        Royal Challengers Bangalore
# Name: 0, dtype: object

# %%
df2.iloc[-1]   #last ball
# Out:
# id                    729313
# inning                     2
# over                       4
# ball                       5
# batsman             V Sehwag
# non_striker          WP Saha
# bowler              AB Dinda
# batsman_runs               4
# extra_runs                 0
# total_runs                 4
# non_boundary               0
# is_wicket                  0
# dismissal_kind           NaN
# player_dismissed           N
# fielder                  NaN
# extras_type              NaN
# batting_team             NaN
# bowling_team             NaN
# Name: 98744, dtype: object

# %%
df1.groupby(['venue','id']).count().droplevel(level=1).index.value_counts()
# Out:
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# ...

# %%
df2.groupby(['batting_team'])['total_runs'].sum().sort_values(ascending= False)
# Out:
# batting_team
# Chennai Super Kings            16325
# Mumbai Indians                 14943
# Royal Challengers Bangalore    14780
# Kings XI Punjab                14554
# Delhi Daredevils               14072
# Rajasthan Royals               13906
# Kolkata Knight Riders          13248
# Deccan Chargers                11463
# Pune Warriors                   6358
# Sunrisers Hyderabad             2881
# Kochi Tuskers Kerala            1901
# Name: total_runs, dtype: int64
